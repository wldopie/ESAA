# %% [markdown]
# <a href="https://colab.research.google.com/github/wldopie/ESAA/blob/main/HW_220325.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **4. 그래프 그리기**

# %% [markdown]
# ---

# %% [markdown]
# ### 4-1. 데이터 시각화가 필요한 이유

# %% [markdown]
# ##### a. **`앤스콤 4분할`** 그래프 살펴보기
#   - 앤스콤이 지적한 함정과 데이터 시각화의 필요성
#     - 데이터 그룹의 `수칫값이나 상관관계, 회귀선이 같다`는 이유로 `각 그룹의 데이터가 모두 같을 것이라고 착각`하는 경우
#     - 이러한 경우 각 `데이터 그룹을 시각화`하면 데이터 그룹이 `서로 다른 데이터 패턴`을 가지고 있다는 것을 알 수 있으므로, `데이터 시각화`는 데이터 분석에서 `매우 중요`

# %%
# 1. 앤스콤 데이터 집합 불러오기
import seaborn as sns

anscombe = sns.load_dataset('anscombe')     # anscombe 데이터 로딩
print(anscombe)                             
print(type(anscombe))                       # anscombe = 데이터프레임 형식
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
# 2. matplotlib 라이브러리로 그래프 그리기
# %matplotlib notebook
# %matplotlib inline      
import matplotlib.pyplot as plt

# %%
# 3. anscombe 데이터프레임에서 dataset이 I인 데이터들만 추출하기
dataset_1 = anscombe[anscombe['dataset'] == 'I']
dataset_1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
# 4. 선 그래프 그리기 : plot(x, y)
plt.plot(dataset_1['x'], dataset_1['y'])

# %%
# 5. 점 그래프 그리기 : plot(x, y, 'o')
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %% [markdown]
# ##### b. 앤스콤 **`데이터 집합 모두 사용`**해 그래프 만들기
#   - 앤스콤 데이터 집합은 `총 4개의 데이터` 그룹으로 구성되어 있으므로, 모든 데이터 그룹에 대해 그래프 출력
#   - **`matplotlib 라이브러리`**로 그래프 그리기
#     - 1. 전체 그래프가 위치할 `기본 틀`
#     - 2. 그래프를 그려 넣을 `그래프 격자`
#     - 3. 그런 다음 격자에 `그래프를 하나씩 추가`, 순서는 왼쪽에서 오른쪽
#     - 4. 격자의 `첫 번째 행이 꽉 차면 두 번째 행`에 그래프 출력

# %%
# 1. dataset 값이 I, II, III, IV인 것을 불리언 추출하여 dataset_1,2,3,4에 저장
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %%
# 2. 그래프 격자가 위치할 기본 틀
fig = plt.figure()

# 3. 그래프 격자 출력 : add_subplot(# of rows, # of columns)
axes1 = fig.add_subplot(2,2,1)      # (2,2) 격자에서 1번째 칸에 출력
axes2 = fig.add_subplot(2,2,2)      # (2,2) 격자에서 2번째 칸에 출력
axes3 = fig.add_subplot(2,2,3)      # (2,2) 격자에서 3번째 칸에 출력
axes4 = fig.add_subplot(2,2,4)      # (2,2) 격자에서 4번째 칸에 출력

# %%
# 4. 점 그래프 그리기
axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

fig       # 그래프를 확인하기 위해서는 반드시 fig 입력

# %%
# 5. 그래프 격자에 제목 추가하기 : set_title()
axes1.set_title('dataset_1')
axes2.set_title('dataset_2')
axes3.set_title('dataset_3')
axes4.set_title('dataset_4')

fig         # 그래프를 확인하기 위해서는 항상 fig 입력

# %%
# 6. 기본 틀(fig)에 제목 추가 : suptitle()
fig.suptitle('Anscombe Data')

fig

# %%
# 7. 그래프의 레이아웃 조절 : tight_layout()
fig.tight_layout()

fig     # 위에서 그래프의 이름과 숫자가 겹쳤던 것을 해결해줌

# %% [markdown]
# ---

# %% [markdown]
# ### 4-2. ***`matplotlib 라이브러리`*** 자유자재로 사용하기

# %% [markdown]
# ##### a. `기초 그래프` 그리기 - **`히스토그램`**, **`산점도 그래프`**, **`박스 그래프`**

# %%
# 1. tips 데이터 집합을 불러와 변수 tips에 저장하기
tips = sns.load_dataset('tips')
print(tips.head())      # 지불 금액, 팁, 성별, 흡연 유무, 요일, 시간, 전체 인원
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
# 2. 그래프의 기본 틀(fig)을 마련하고 그래프 격자(axes1) 구성하기
fig = plt.figure()

axes1 = fig.add_subplot(1,1,1)

# %%
# 3. total_bill 칼럼으로 히스토그램 그리기 : hist()
# 변수를 하나만 사용하므로, "일변량 그래프" 또는 "단변량 그래프"
axes1.hist(tips['total_bill'], bins=10)       # x축의 간격이 10인 히스토그램
axes1.set_title('Histogram of Total Bill')    # 그래프 제목 설정
axes1.set_xlabel('Frequency')                 # x축 제목 설정
axes1.set_ylabel('Total Bill')                # y축 제목 설정

fig

# %%
# 4. total_bill, tip 칼럼으로 산점도 그래프 그리기 : scatter()
# 두 가지의 변수를 사용하므로, "이변량 그래프"

scatter_plot = plt.figure()                             # 그래프 기본 틀 설정   
axes1 = scatter_plot.add_subplot(1,1,1)           

axes1.scatter(tips['total_bill'], tips['tip'])         # x = total_bill, y = tips인 산점도 
axes1.set_title('Scatterplot of Total Bill vs. Tip')    # 그래프 제목 설정
axes1.set_xlabel('Total Bill')                          # x축 제목 설정
axes1.set_ylabel('Tip')                                 # y축 제목 설정

# 왜 산점도 그래프는 위에서와 같이 "fig"를 입력하지 않아도 출력되는지?
# Out:
# Text(0, 0.5, 'Tip')

# %%
# 5. 이산형 변수(sex)와 연속형 변수(tip)를 이용하여 박스 그래프 그리기 : boxplot()

boxplot = plt.figure()                # 그래프의 기본 틀 설정
axes1 = boxplot.add_subplot(1,1,1)   

axes1.boxplot([tips[tips['sex'] == 'Female']['tip'],     # 여성인 사람들의 tip 값 추출
               tips[tips['sex'] == 'Male']['tip']],      # 남성인 사람들의 tip 값 추출
               labels = ['Female', 'Male'])

axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# ##### b. **`다변량 그래프`** 그리기
#   - `다변량 그래프`
#     - **`3개 이상의 변수`**를 사용한 그래프
#   - 다변량 그래프가 필요한 이유?
#     - 적재적소에 맞는 그래프 요소를 추가하여 3개 이상의 변수를 잘 표현할 수 있도록 하는 그래프를 출력하기 위함

# %%
# 1. 앞에서 실습한 산점도 그래프에 성별을 새 변수로 추가하기
# 성별은 서로 다른 색으로 구분
# Male, Female을 각각 1, 0으로 변환하는 함수
def recode_sex(sex):
  if sex == 'Female':
    return 0
  else:
    return 1

# %%
# 2. recode_sex가 반환한 값을 데이터프레임에 새로운 열로 추가
tips['sex_color'] = tips['sex'].apply(recode_sex)       # apply 함수 사용

# %%
# 3. 테이블당 인원 수를 산점도 그래프에 추가하기 
# 테이블당 인원 수는 점의 크기로 구분

scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x = tips['total_bill'],
    y = tips['tip'],
    s = tips['size'] * 10,
    c = tips['sex_color'],
    alpha = 0.5             # 점의 투명도를 조절하는 파라미터
)

axes1.set_title('Total Bill vs. Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ---

# %% [markdown]
# ### 4-3. ***`seaborn 라이브러리`*** 자유자재로 사용하기

# %% [markdown]
# ##### a. **`단변량 그래프`** 그리기 - **`히스토그램`**

# %%
# 1. tips 데이터 집합 불러오기
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
# 2. seaborn 라이브러리로 히스토그램 그리기 : subplots(), distplots()
# subplot() : 기본 틀 형성 / distplot() : 히스토그램, 밀집도 그래프 출력

ax = plt.subplots()                                      
ax = sns.distplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %%
# 3. distplot() 메서드에서 히스토그램만 출력하기

ax = plt.subplots()                                      
ax = sns.distplot(tips['total_bill'], kde=False)          # kde = False : 밀집도 그래프를 제외하고 출력
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %%
# 4. distplot() 메서드에서 밀집도 그래프만 출력

ax = plt.subplots( )
ax = sns.distplot(tips['total_bill'], hist=False)         # hist = False : 밀집도 그래프만 출력
ax.set_title('Total Bill Density') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Unit Probability')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Unit Probability')

# %%
# 5. distplot() 메서드에 rug 인자 추가하기
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], rug=True)
ax.set_title('Total Bill Histogram with Density and Rug Plot')
ax.set_xlabel('Total Bill')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Total Bill')

# %%
# 6. count 그래프 출력하기 : countplot()
ax = plt.subplots( )
ax = sns.countplot('day', data=tips)
ax.set_title('Count of days') 
ax.set_xlabel('Day of the Week') 
ax.set_ylabel('Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ##### b. 다양한 종류의 **`이변량 그래프`** 그리기

# %%
# 1. 산점도 그래프 그리기 : regplot()을 통해 산점도 그래프, 회귀선 출력
ax = plt.subplots( )
ax = sns.regplot(x = 'total_bill', y = 'tip', data=tips)    # 산점도, 회귀선 모두 출력 
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
# 산점도 그래프만 출력하려면 fit_reg = False로 지정
ax = plt.subplots( )
ax = sns.regplot(x = 'total_bill', y = 'tip', data=tips, fit_reg=False)   # 산점도만 출력
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
# 2. 산점도 그래프와 히스토그램을 한 번에 그리기 : jointplot(x, y, data)
joint = sns.jointplot(x = 'total_bill', y = 'tip', data=tips) 
joint.set_axis_labels(xlabel = 'Total Bill', ylabel = 'Tip') 
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
# 3. 육각형 그래프 그리기 : jointplot(x,y,data, kind='hex')
# 산점도 그래프의 경우 점이 겹치면 구분하기 어려우므로, 이를 보완하는 그래프
joint = sns.jointplot(x = 'total_bill', y = 'tip', data=tips, kind='hex') 
joint.set_axis_labels(xlabel = 'Total Bill', ylabel = 'Tip') 
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
# 4. 이차원 밀집도 그리기 : kdeplot()
ax = plt.subplots( )
ax = sns.kdeplot(data = tips['total_bill'],
                 data2 = tips['tip'],
                 shade=True)            # 그래프에 음영 효과를 줄 수 있음

ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1681: FutureWarning: Use `x` and `y` rather than `data` `and `data2`
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Tip')

# %%
# 5. 바(bar) 그래프 그리기 : barplot()
# 바 그래프는 지정한 변수의 평균을 계산하여 그릴 수 있음

ax = plt.subplots( )
ax = sns.barplot(x = 'time', y = 'total_bill', data=tips) 
ax.set_title('Bar plot of average total bill for time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %%
# 6. 박스 그래프 그리기 : boxplot()
# 박스 그래프 : min, Q1, median, Q3, max, outlier 등 다양한 통계량을 한 번에 표현
ax = plt.subplots( )
ax = sns.boxplot(x = 'time', y = 'total_bill', data=tips) 
ax.set_title('Boxplot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
# 7. 바이올린 그래프 그리기 : violinplot()
# 박스 그래프는 데이터의 분산이 모호하게 표현되므로, 이를 명확하게 하기 위한 그래프

ax = plt.subplots( )
ax = sns.violinplot(x = 'time', y = 'total_bill', data=tips) 
ax.set_title('Violin plot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
# 8. 관계 그래프 그리기 : pairplot(dataframe)
fig = sns.pairplot(tips)

# %%
# 9. 관계 그래프의 중복성을 제거하고 원하는 그래프로 채워넣기 : PairGrid(dataframe)
# map_upper : 대각선을 중심으로 위쪽에 그릴 그래프 지정 (산점도 그래프)
# map_lower : 대각선을 중심으로 아래쪽에 그릴 그래프 지정 (이차원 밀집도)
# map_diag : 대각선을 중심으로 그래프 출력 (히스토그램, 밀집도)

pair_grid = sns.PairGrid(tips) 
pair_grid = pair_grid.map_upper(sns.regplot) 
pair_grid = pair_grid.map_lower(sns.kdeplot) 
pair_grid = pair_grid.map_diag(sns.distplot, rug=True) 
plt.show( )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ##### c. **`다변량 그래프`** 그리기

# %%
# 1. seaborn 라이브러리로 바이올린 그래프 그리기 - 색상 추가
# hue 인잣값으로 색상에 사용할 열 이름 추가
ax = plt.subplots()
ax = sns.violinplot(x = 'time', y = 'total_bill', hue='sex', data=tips, split=True)

# %%
# 2. 산점도, 관계 그래프 그리기 - 색상 추가
# 산점도 그래프 : lmplot()
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False)

# 관계 그래프 : pairplot()
fig = sns.pairplot(tips, hue='sex')

# %%
# 3. 산점도 그래프의 크기와 모양 조절하기
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',
                     scatter_kws = {'s' : tips['size']*10})
# 왜 에러가 날까?
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-bfff85d0c78a> in <module>()
#       1 # 3. 산점도 그래프의 크기와 모양 조절하기
#       2 scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',
# ----> 3                      scatter_kws = {'s' : tips['size']*10})
#       4 # 왜 에러가 날까?
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
# 4. 산점도 그래프의 점을 다른 기호로 표현하기
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',
                     markers = ['o', 'x'], scatter_kws = {'s' : tips['size']*10})
# 왜 에러가 날까?
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-109120f9bd94> in <module>()
#       1 # 4. 산점도 그래프의 점을 다른 기호로 표현하기
#       2 scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',
# ----> 3                      markers = ['o', 'x'], scatter_kws = {'s' : tips['size']*10})
#       4 # 왜 에러가 날까?
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
# 5. Implot 메서드로 4개의 데이터 그룹에 대한 그래프 한 번에 그리기
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False)    # 4개의 데이터 그룹이 한꺼번에 출력

# %%
# 6. 그룹별로 데이터 출력
# col = 'dataset' : 데이터 그룹을 구분할 열 (dataset = 1, 2, 3, 4로 각각 구분)
# col_wrap = 2 : 그래프를 그릴 열의 최댓값 (2개의 열로 그래프를 출력)
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False,
                           col='dataset', col_wrap=2)

# %% [markdown]
# ##### Plus : FacetGrid 클래스로도 그룹별 그래프를 그릴 수 있습니다!

# %%
facet = sns.FacetGrid(tips, col='time')
facet.map(sns.distplot, 'total_bill', rug=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# 다변량 그래프
facet = sns.FacetGrid(tips, col='day', hue='sex')
facet = facet.map(plt.scatter, 'total_bill', 'tip')     # 그래프 종류, x축, y축
facet = facet.add_legend()

# %%
# 더 많은 변수 사용
facet = sns.FacetGrid(tips, col='time', row='smoker', hue='sex')
facet.map(plt.scatter, 'total_bill', 'tip')

# %% [markdown]
# ---

# %% [markdown]
# ### 4-4. 데이터프레임과 시리즈로 그래프 그리기

# %%
# 1. 히스토그램 그리기 : series.plot.hist()
ax = plt.subplots()
ax = tips['total_bill'].plot.hist()

# %%
# 2. tips 데이터프레임에서 2개의 시리즈를 선택하여 히스토그램 그리기
# alpha : 투명도, bins : x축의 간격
fig, ax = plt.subplots()              # 2개의 시리즈를 활용했으므로 fig, ax 2개를 변수로 지정
ax = tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=ax)

# %%
# 3. 밀집도, 산점도 그래프, 육각 그래프 그리기

# 밀집도 : series.plot.kde()
ax = plt.subplots()
ax = tips['tip'].plot.kde()
ax.set_title('Density Function of Tip')

# 산점도 : dataframe.plot.scatter()
fig, ax = plt.subplots()
ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax)
ax.set_title('Total Bills vs. Tip')

# 육각 그래프 : dataframe.plot.hexbin()
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax)
ax.set_title('Hexagonal Graph of Total bill vs. Tip')
# Out:
# Text(0.5, 1.0, 'Hexagonal Graph of Total bill vs. Tip')

# %%
# 4. 육각 그래프의 육각형 크기 조절하기 : dataframe.plot.hexbin(gridsize=10)
# gridsize 파라미터를 활용해 조절
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=10, ax=ax)

# %%
# 5. 박스 그래프 그리기 : dataframe.plot.box()
fig, ax = plt.subplots()
ax = tips.plot.box(ax=ax)

# %% [markdown]
# ---

# %% [markdown]
# ### 4-5. **`seaborn`** 라이브러리로 **`그래프 스타일`** 설정하기
#   - seaborn 라이브러리 스타일
#     : darkgrid, whitegrid, dark, white, ticks

# %%
# 1. 기본적인 violinplot 그리기
fig, ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
# 2. whitegrid로 스타일 설정하기
sns.set_style('whitegrid')
fig, ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
# 3. for문을 이용해 그래프에 모든 스타일을 하나씩 적용하기 
fig = plt.figure()

seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']

for idx, style in enumerate(seaborn_styles):
  plot_position = idx + 1
  with sns.axes_style(style):
    ax = fig.add_subplot(2, 3, plot_position)
    violin = sns.violinplot(x='time', y='total_bill', data=tips, ax=ax)
    violin.set_title(style)

fig.tight_layout()
